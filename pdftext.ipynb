# %%
import tabula

dfs = tabula.read_pdf(
	"/Users/ijunhui/Downloads/ubion/Project1-다줘페이/2022년 6월 소비자 빅데이터 트렌드_본보고서.pdf", 
	pages="all", 
	stream=True
)
print(f"Data Type :{type(dfs)}")
print(f"Data Length: {len(dfs)}")
for index, table in enumerate(dfs):
  print(f"\nData Index: {index}")
  print(type(table))
  print(table.head())
# Out:
# Data Type :<class 'list'>
# Data Length: 16
#
# Data Index: 0
# <class 'pandas.core.frame.DataFrame'>
#    순위        품목명    증가율  순위.1         품목명.1  증가율.1
# 0   1        에어컨  107.0     1          실손보험  280.9
# 1   2   인터넷교육서비스   51.0     2     항공여객운송서비스  178.0
# 2   3  항공여객운송서비스   28.3     3        신유형상품권   56.2
# 3   4        냉장고   26.0     4  건강(암·기타질병)보험   47.2
# 4   5         TV   20.1     5      인터넷교육서비스   31.5
#
# Data Index: 1
# <class 'pandas.core.frame.DataFrame'>
#           네일아트 관련 소비자이슈(‘22.6.7.) 1위   유사투자자문  1,456건(3.3%)
# 0              ‘주식회사 L사’ 배송지연 및 연락두절      NaN           NaN
# 1  1,285건(2.9%)관련 소비자이슈(‘22.6.16.)2위      헬스장           NaN
# 2            ‘주식회사 I사’ 배송지연 및 장학금 3위  이동전화서비스  1,130건(2.6%)
# 3            미지급 관련 소비자이슈(‘22.6.17.)      NaN           NaN
# 4                                 4위    의류・섬유    962건(2.2%)
#
# Data Index: 2
# <class 'pandas.core.frame.DataFrame'>
#          구분 2021. 6. 2022. 5. 2022. 6.
# 0     상담 건수   51,649   44,866   44,094
# 1     전월 대비    12.3%     5.8%   - 1.7%
# 2  전년 동월 대비   -14.0%   - 2.4%   -14.6%
#
# Data Index: 3
# <class 'pandas.core.frame.DataFrame'>
#     구분   6월            7월                8월
# 0  NaN  NaN    블라우스, 원피스,               NaN
# 1  NaN  NaN           NaN      가스에어컨, 룸에어컨,
# 2  NaN  NaN  각종내의류, 각종가방,               NaN
# 3  NaN  NaN           NaN  시스템에어컨, 냉장고, TV,
# 4  소비자  NaN           NaN               NaN
#
# Data Index: 4
# <class 'pandas.core.frame.DataFrame'>
#    순위        품목명     증가율  순위.1         품목명.1   증가율.1
# 0   1        에어컨  107.0%     1          실손보험  280.9%
# 1   2   인터넷교육서비스   51.0%     2     항공여객운송서비스  178.0%
# 2   3  항공여객운송서비스   28.3%     3        신유형상품권   56.2%
# 3   4        냉장고   26.0%     4  건강(암·기타질병)보험   47.2%
# 4   5         TV   20.1%     5      인터넷교육서비스   31.5%
#
# Data Index: 5
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 2022. 5.    2022. 6.              Unnamed: 2
# 0         순위        품목명      NaN         NaN                 주요 상담사례
# 1        NaN        NaN       건수      건수 증가율                     NaN
# 2        NaN        NaN      NaN         NaN  - 냉방 능력 저하로 A/S를 요청했으나
# 3          1        에어컨      315  652 107.0%                     NaN
# 4        NaN        NaN      NaN         NaN                    지연됨.
#
# Data Index: 6
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 2021. 6.    2022. 6.          Unnamed: 2
# 0         순위        품목명      NaN         NaN             주요 상담사례
# 1        NaN        NaN       건수      건수 증가율                 NaN
# 2        NaN        NaN      NaN         NaN  - 백내장 수술 후 보험금 지급이
# 3          1       실손보험      110  419 280.9%                 NaN
# 4        NaN        NaN      NaN         NaN     지연되어 관련 내용 문의함.
#
# Data Index: 7
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0             2021. 6. 2022. 5.           2022. 6. Unnamed: 1
# 0          순                        증감률품목명                NaN        NaN
# 1          위                   건수 비율 건수 비율           건수 비율 전년        NaN
# 2        NaN                           NaN                NaN      전월 대비
# 3        NaN                           NaN              동월 대비        NaN
# 4          1  유사투자자문 2,359 4.6% 1,692 3.8%  1,456 3.3% -38.3%     -13.9%
#
# Data Index: 8
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0                6월 초순                 6월 중순                 6월 하순
# 0          순  (2022.6.1. ~ 6.10.)  (2022.6.11. ~ 6.20.)  (2022.6.21. ~ 6.30.)
# 1          위                  NaN                   NaN                   NaN
# 2        NaN               품목명 건수                품목명 건수                품목명 건수
# 3          1           유사투자자문 464            유사투자자문 418            유사투자자문 574
# 4          2              헬스장 440           이동전화서비스 379               헬스장 468
#
# Data Index: 9
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1    2022. 6.         Unnamed: 2
# 0         순위        품목명         NaN            주요 상담사례
# 1        NaN        NaN       건수 비율                NaN
# 2        NaN        NaN         NaN    - 유사투자자문업체에 환급을
# 3          1     유사투자자문  1,456 3.3%  요청했으나 사업자는 이를 거부한
# 4        NaN        NaN         NaN           후 연락두절됨.
#
# Data Index: 10
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 2021. 6. 2022. 5. Unnamed: 1     2022. 6. Unnamed: 2
# 0        연령대      NaN      NaN        NaN          증감률        NaN
# 1        NaN    건수 비율    건수 비율         건수        비율 전년        NaN
# 2        NaN      NaN      NaN        NaN          NaN       전월대비
# 3        NaN      NaN      NaN        NaN         동월대비        NaN
# 4     10대 이하  85 0.2%  79 0.2%         78  0.2% - 8.2%     - 1.3%
#
# Data Index: 11
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 2021. 6. 2022. 5. Unnamed: 2 2022. 6. Unnamed: 3
# 0        NaN       상담사유      NaN      NaN        NaN      증감률        NaN
# 1        NaN        NaN    건수 비율    건수 비율         건수    비율 전년        NaN
# 2        NaN        NaN      NaN      NaN        NaN      NaN       전월대비
# 3        NaN        NaN      NaN      NaN        NaN     동월대비        NaN
# 4         품질        NaN      NaN      NaN        NaN      NaN        NaN
#
# Data Index: 12
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 2021. 6. 2022. 5. Unnamed: 2 2022. 6. Unnamed: 3
# 0        NaN        NaN      NaN      NaN        NaN      증감률        NaN
# 1        NaN       판매방법      NaN      NaN        NaN      NaN        NaN
# 2        NaN        NaN    건수 비율    건수 비율         건수    비율 전년        NaN
# 3        NaN        NaN      NaN      NaN        NaN      NaN       전월대비
# 4        NaN        NaN      NaN      NaN        NaN     동월대비        NaN
#
# Data Index: 13
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 2021. 6. 2022. 5. Unnamed: 2 2022. 6.
# 0         순위        NaN      NaN      NaN        NaN      NaN
# 1        (현월        품목명      NaN      NaN        NaN      증감률
# 2        NaN        NaN    건수 비율    건수 비율         건수       비율
# 3        기준)        NaN      NaN      NaN        NaN  전년 전월대비
# 4        NaN        NaN      NaN      NaN        NaN     동월대비
#
# Data Index: 14
# <class 'pandas.core.frame.DataFrame'>
#    순위        품목명     증감률  순위.1       품목명.1   증감률.1
# 0   1     점퍼·재킷류  -36.8%     1  모바일정보이용서비스  -40.9%
# 1   2       실손보험  -29.6%     2   자동차대여(렌트)  -38.4%
# 2   3  자동차대여(렌트)  -23.5%     3      유사투자자문  -38.3%
# 3   4        피부과  -22.8%     4     이동전화서비스  -37.8%
# 4   5      미용서비스  -17.6%     5     중형승용자동차  -37.4%
#
# Data Index: 15
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 인구 10만 명당 Unnamed: 3     증감률
# 0      거주 지역       상담건수         비율       NaN         전년     NaN
# 1        NaN        NaN        NaN     상담 건수        NaN   전월 대비
# 2        NaN        NaN        NaN       NaN      동월 대비     NaN
# 3        경기도     13,242      30.0%      97.5     -15.9%  - 0.3%
# 4      서울특별시      9,358      21.2%      98.6     -16.7%  - 4.5%
