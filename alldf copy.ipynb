# %%
import pandas as pd

pct_df = pd.read_excel('/Users/ijunhui/Downloads/ubion/Project1-다줘페이/data/카드총액증감율09~22.xlsx')
pct_df = pct_df.dropna()

pct_df.columns = pct_df.columns.str.replace(" ", "")
pct_df = pct_df.rename(columns={'소비유형코드' : '날짜'})
# pct_df['날짜'] = pd.to_datetime(pct_df["날짜"], format='%Y/%M') 
# pct_df['날짜'] = pct_df["날짜"].dt.strftime('%Y%m')   
# 

pct_df['날짜'] = pct_df['날짜'].str.replace("/", "")
#pct_df = pct_df.set_index(keys='날짜')
pct_df.columns
# Out:
# Index(['날짜', '전자상거래/통신판매', '식료품', '의류/잡화', '연료', '가구/가전', '의료/보건', '자동차',
#        '여행/교통', '스포츠/오락/여가', '서적/문구', '교육', '숙박', '음식점', '공과금/개인및전문서비스',
#        '금융/보험'],
#       dtype='object')

# %%
pct_df['월'] = pct_df['날짜'].str[-2:]
pct_df['월'] = pct_df['월'].astype(int)
pct_df
# Out:
#          날짜  전자상거래/통신판매   식료품  의류/잡화    연료  가구/가전  의료/보건   자동차  여행/교통  \
# 1    201001        -9.1 -10.7  -18.0  -9.6  -17.8   -1.8 -42.6   -6.4
# 2    201002        -6.9  22.1    0.3  -4.0   -0.7   -5.8   2.1   -7.5
# 3    201003        15.7 -14.4   15.8  14.1   46.0   13.6  16.7   10.6
# 4    201004        -8.5  -0.7    0.8   0.3  -24.1   -3.3 -14.3    8.6
# 5    201005         2.0   9.7    9.5  -1.7    5.1   -4.2  -4.0    5.3
# ..      ...         ...   ...    ...   ...    ...    ...   ...    ...
# 144  202112         1.6   2.7   -5.1  -0.1  -11.4    5.5   4.7  -19.6
# 145  202201        -0.3  28.4   -9.7  -1.9   11.3    2.2 -22.4    3.5
# 146  202202        -9.6 -37.9  -18.8 -10.7   -7.5  -12.7  -0.2  -16.0
# 147  202203        13.2  11.4   23.5  20.3    4.2   15.9  12.2   26.1
# 148  202204        -3.3   6.5   14.3   6.0   -2.9   -3.3   8.5   29.9
#
#      스포츠/오락/여가  서적/문구    교육    숙박   음식점  공과금/개인및전문서비스  금융/보험   월
# 1        -17.8  -14.5  -7.1 -12.8 -13.7           4.6  -11.0   1
# 2         -9.0   -6.2   1.2 -19.1  -9.7          -7.9   -4.2   2
# 3         32.1   54.4  16.4  11.7  23.0           3.2   24.2   3
# 4          0.3  -30.9 -15.8  20.8  -2.9           3.4  -14.2   4
# 5         12.4   -5.8   9.9   6.7   9.0          -3.9   -3.9   5
# ..         ...    ...   ...   ...   ...           ...    ...  ..
# 144      -21.0   18.6   4.0  -0.2  -8.6           8.7    5.3  12
# 145      -12.7   -5.1   3.2  -4.0  -6.1          19.6   -7.0   1
# 146       -7.9  -16.4  -8.3  -7.1 -17.4         -24.0   -5.0   2
# 147       39.8   40.3  10.7  -8.8  21.5           8.1   18.0   3
# 148       21.3  -19.5  -8.6  11.6  19.7           0.9   -7.0   4
#
# [148 rows x 17 columns]

# %%
#pct_df_m = pct_df.groupby('월').mean()
cl = pct_df_m.columns
    # print(i, '의 하위 월 : ', pct_df_m.sort_values(i)[i].head(3), )
    # print(i, '의 상위 월 : ', pct_df_m.sort_values(i, ascending=False)[i].head(3))

for i in cl:
    print(i, '의 하위 월 : ', pct_df_m.sort_values(i)[i].head(5).index)
    print(i, '의 상위 월 : ', pct_df_m.sort_values(i, ascending=False)[i].head(5).index)
# Out:
# 전자상거래/통신판매 의 하위 월 :  Int64Index([2, 8, 4, 1, 6], dtype='int64', name='월')
# 전자상거래/통신판매 의 상위 월 :  Int64Index([3, 7, 10, 12, 11], dtype='int64', name='월')
# 식료품 의 하위 월 :  Int64Index([10, 6, 2, 11, 3], dtype='int64', name='월')
# 식료품 의 상위 월 :  Int64Index([9, 1, 5, 8, 12], dtype='int64', name='월')
# 의류/잡화 의 하위 월 :  Int64Index([1, 6, 8, 2, 7], dtype='int64', name='월')
# 의류/잡화 의 상위 월 :  Int64Index([3, 10, 9, 5, 4], dtype='int64', name='월')
# 연료 의 하위 월 :  Int64Index([2, 9, 1, 6, 4], dtype='int64', name='월')
# 연료 의 상위 월 :  Int64Index([3, 7, 5, 10, 8], dtype='int64', name='월')
# 가구/가전 의 하위 월 :  Int64Index([9, 4, 12, 8, 2], dtype='int64', name='월')
# 가구/가전 의 상위 월 :  Int64Index([3, 7, 5, 11, 10], dtype='int64', name='월')
# 의료/보건 의 하위 월 :  Int64Index([2, 9, 4, 6, 11], dtype='int64', name='월')
# 의료/보건 의 상위 월 :  Int64Index([3, 10, 7, 12, 1], dtype='int64', name='월')
# 자동차 의 하위 월 :  Int64Index([1, 8, 2, 4, 5], dtype='int64', name='월')
# 자동차 의 상위 월 :  Int64Index([3, 12, 10, 9, 11], dtype='int64', name='월')
# 여행/교통 의 하위 월 :  Int64Index([2, 9, 8, 6, 1], dtype='int64', name='월')
# 여행/교통 의 상위 월 :  Int64Index([7, 4, 10, 5, 3], dtype='int64', name='월')
# 스포츠/오락/여가 의 하위 월 :  Int64Index([1, 12, 6, 2, 11], dtype='int64', name='월')
# 스포츠/오락/여가 의 상위 월 :  Int64Index([3, 10, 5, 4, 8], dtype='int64', name='월')
# 서적/문구 의 하위 월 :  Int64Index([4, 1, 2, 8, 10], dtype='int64', name='월')
# 서적/문구 의 상위 월 :  Int64Index([3, 12, 7, 9, 11], dtype='int64', name='월')
# 교육 의 하위 월 :  Int64Index([9, 4, 6, 2, 10], dtype='int64', name='월')
# 교육 의 상위 월 :  Int64Index([5, 7, 12, 3, 8], dtype='int64', name='월')
# 숙박 의 하위 월 :  Int64Index([9, 2, 1, 11, 6], dtype='int64', name='월')
# 숙박 의 상위 월 :  Int64Index([8, 5, 10, 12, 7], dtype='int64', name='월')
# 음식점 의 하위 월 :  Int64Index([9, 2, 1, 6, 11], dtype='int64', name='월')
# 음식점 의 상위 월 :  Int64Index([3, 5, 10, 12, 7], dtype='int64', name='월')
# 공과금/개인및전문서비스 의 하위 월 :  Int64Index([2, 8, 11, 5, 10], dtype='int64', name='월')
# 공과금/개인및전문서비스 의 상위 월 :  Int64Index([7, 1, 9, 12, 4], dtype='int64', name='월')
# 금융/보험 의 하위 월 :  Int64Index([4, 1, 2, 8, 11], dtype='int64', name='월')
# 금융/보험 의 상위 월 :  Int64Index([3, 12, 7, 10, 5], dtype='int64', name='월')

# %%
pct_index = pct_df_m.transpose()
#pct_index.index
for i in range(1, 13):
    print(i, '월의 가장 낮은 품목은 : ', pct_index.sort_values(i).head(5).index)
    print(i, '월의 가장 높은 품목은 : ', pct_index.sort_values(i, ascending=False).head(5).index)
    print('\n')
# Out:
# 1 월의 가장 낮은 품목은 :  Index(['자동차', '의류/잡화', '스포츠/오락/여가', '서적/문구', '음식점'], dtype='object')
# 1 월의 가장 높은 품목은 :  Index(['공과금/개인및전문서비스', '식료품', '의료/보건', '여행/교통', '교육'], dtype='object')
#
#
# 2 월의 가장 낮은 품목은 :  Index(['공과금/개인및전문서비스', '숙박', '여행/교통', '음식점', '의료/보건'], dtype='object')
# 2 월의 가장 높은 품목은 :  Index(['교육', '가구/가전', '금융/보험', '자동차', '스포츠/오락/여가'], dtype='object')
#
#
# 3 월의 가장 낮은 품목은 :  Index(['식료품', '숙박', '교육', '공과금/개인및전문서비스', '여행/교통'], dtype='object')
# 3 월의 가장 높은 품목은 :  Index(['서적/문구', '스포츠/오락/여가', '자동차', '가구/가전', '의류/잡화'], dtype='object')
#
#
# 4 월의 가장 낮은 품목은 :  Index(['서적/문구', '교육', '가구/가전', '금융/보험', '전자상거래/통신판매'], dtype='object')
# 4 월의 가장 높은 품목은 :  Index(['여행/교통', '스포츠/오락/여가', '공과금/개인및전문서비스', '의류/잡화', '숙박'], dtype='object')
#
#
# 5 월의 가장 낮은 품목은 :  Index(['공과금/개인및전문서비스', '서적/문구', '자동차', '의료/보건', '금융/보험'], dtype='object')
# 5 월의 가장 높은 품목은 :  Index(['숙박', '스포츠/오락/여가', '가구/가전', '교육', '식료품'], dtype='object')
#
#
# 6 월의 가장 낮은 품목은 :  Index(['의류/잡화', '스포츠/오락/여가', '식료품', '음식점', '서적/문구'], dtype='object')
# 6 월의 가장 높은 품목은 :  Index(['공과금/개인및전문서비스', '자동차', '금융/보험', '여행/교통', '가구/가전'], dtype='object')
#
#
# 7 월의 가장 낮은 품목은 :  Index(['의류/잡화', '스포츠/오락/여가', '식료품', '자동차', '연료'], dtype='object')
# 7 월의 가장 높은 품목은 :  Index(['공과금/개인및전문서비스', '가구/가전', '여행/교통', '서적/문구', '교육'], dtype='object')
#
#
# 8 월의 가장 낮은 품목은 :  Index(['공과금/개인및전문서비스', '의류/잡화', '자동차', '가구/가전', '여행/교통'], dtype='object')
# 8 월의 가장 높은 품목은 :  Index(['숙박', '식료품', '교육', '음식점', '연료'], dtype='object')
#
#
# 9 월의 가장 낮은 품목은 :  Index(['숙박', '가구/가전', '교육', '음식점', '여행/교통'], dtype='object')
# 9 월의 가장 높은 품목은 :  Index(['식료품', '의류/잡화', '공과금/개인및전문서비스', '자동차', '서적/문구'], dtype='object')
#
#
# 10 월의 가장 낮은 품목은 :  Index(['식료품', '서적/문구', '교육', '공과금/개인및전문서비스', '연료'], dtype='object')
# 10 월의 가장 높은 품목은 :  Index(['스포츠/오락/여가', '의류/잡화', '숙박', '음식점', '여행/교통'], dtype='object')
#
#
# 11 월의 가장 낮은 품목은 :  Index(['공과금/개인및전문서비스', '숙박', '스포츠/오락/여가', '음식점', '식료품'], dtype='object')
# 11 월의 가장 높은 품목은 :  Index(['가구/가전', '전자상거래/통신판매', '자동차', '서적/문구', '여행/교통'], dtype='object')
#
#
# 12 월의 가장 낮은 품목은 :  Index(['스포츠/오락/여가', '가구/가전', '의류/잡화', '연료', '여행/교통'], dtype='object')
# 12 월의 가장 높은 품목은 :  Index(['서적/문구', '숙박', '자동차', '음식점', '금융/보험'], dtype='object')

# %%
pct_df_m.sort_index()
# Out:
#     전자상거래/통신판매        식료품      의류/잡화         연료      가구/가전     의료/보건  \
# 월
# 1    -3.323077  11.976923 -14.600000  -4.100000  -1.961538  2.876923
# 2    -8.538462  -8.523077  -7.584615  -8.346154  -2.892308 -9.361538
# 3    12.715385  -2.607692  18.176923  11.684615  21.476923  9.523077
# 4    -3.569231   1.461538   2.907692  -2.684615 -11.030769 -2.776923
# 5     3.791667  11.625000  11.466667   3.225000  12.725000  0.716667
# 6    -1.425000  -9.600000 -12.083333  -3.175000  -0.700000 -1.758333
# 7     6.041667  -0.725000  -5.725000   4.450000  17.025000  5.650000
# 8    -4.241667   8.158333 -11.650000   3.166667  -8.550000 -0.266667
# 9     1.766667  29.891667  14.716667  -5.533333 -15.066667 -5.241667
# 10    5.200000 -20.266667  15.983333   3.200000   5.266667  5.975000
# 11    5.083333  -2.816667   0.283333   0.933333   9.175000 -0.475000
# 12    5.200000   3.800000  -3.191667   2.191667  -9.208333  5.233333
#
#           자동차      여행/교통  스포츠/오락/여가      서적/문구         교육         숙박  \
# 월
# 1  -22.323077   1.200000 -13.984615  -9.446154   1.123077  -5.530769
# 2   -5.176923 -13.815385  -6.646154  -7.723077  -0.807692 -14.030769
# 3   25.676923   5.053846  30.515385  40.161538   4.030769  -1.492308
# 4   -2.261538  10.407692   6.876923 -23.476923 -11.515385   2.876923
# 5    0.325000   6.391667  14.508333  -1.708333  12.366667  16.908333
# 6    1.241667  -0.425000 -10.908333  -4.941667  -3.375000  -4.358333
# 7    1.983333  13.016667  -3.808333  11.325000  10.916667   8.958333
# 8  -10.633333  -8.325000  -1.116667  -6.008333   3.650000  29.025000
# 9    4.358333  -8.733333  -1.500000   3.391667 -12.591667 -32.516667
# 10   6.441667   6.758333  20.300000  -5.558333  -0.258333  14.666667
# 11   3.975000   1.691667  -4.608333   2.250000   0.583333  -5.066667
# 12  12.841667   3.733333 -13.575000  17.291667   4.516667  13.883333
#
#           음식점  공과금/개인및전문서비스      금융/보험
# 월
# 1   -8.276923     16.315385  -5.792308
# 2  -10.653846    -17.961538  -4.915385
# 3   15.592308      4.369231  15.776923
# 4    1.546154      4.630769  -6.030769
# 5   11.075000     -1.908333   1.933333
# 6   -7.208333      3.241667   0.191667
# 7    5.991667     21.766667   6.008333
# 8    3.366667    -15.833333  -3.591667
# 9  -11.941667      7.941667  -1.133333
# 10   8.375000      1.625000   4.891667
# 11  -3.008333     -7.325000  -1.800000
# 12   7.283333      5.133333   6.150000

# %%
spi = pd.read_excel('/Users/ijunhui/Downloads/ubion/Project1-다줘페이/data/소비판매지수09~22.xlsx')
spi = spi.iloc[:-1]
spi['소비판매지수'] = spi['총지수'].pct_change()
spi = spi.dropna()
spi = spi[['시점', '소비판매지수']]
spi = spi.rename(columns={'시점':'날짜'})
spi['날짜'] = spi['날짜'].str.replace(".", "")
  
spi = spi.set_index(keys='날짜')

spi
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_15701/2354941369.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   spi['날짜'] = spi['날짜'].str.replace(".", "")
#           소비판매지수
# 날짜
# 201001 -0.095082
# 201002 -0.016908
# 201003  0.054054
# 201004 -0.018648
# 201005  0.042755
# ...          ...
# 202112  0.020048
# 202201 -0.076258
# 202202 -0.081702
# 202203  0.130677
# 202204 -0.021311
#
# [148 rows x 1 columns]

# %%
cpi = pd.read_csv('./data/소비자물가지수_09~22.csv', encoding='euc-kr')

# cpi = cpi.iloc[:-1]
cpi['소비자물가지수'] = cpi['전국'].pct_change()
cpi = cpi.dropna()
cpi = cpi[['시점', '소비자물가지수']]
cpi = cpi.rename(columns={'시점':'날짜'})
cpi['날짜'] = cpi['날짜'].astype(str)
cpi['날짜'] = cpi['날짜'].str.replace(".", "")
cpi = cpi.set_index(keys='날짜')

cpi
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_15701/1109025084.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cpi['날짜'] = cpi['날짜'].str.replace(".", "")
#          소비자물가지수
# 날짜
# 201001  0.007900
# 201002  0.002015
# 201003  0.002023
# 201004  0.004026
# 201005  0.001011
# ...          ...
# 202112  0.001637
# 202201  0.006248
# 202202  0.005827
# 202203  0.007217
# 202204  0.007449
#
# [148 rows x 1 columns]

# %%
df = pd.merge(pct_df, spi, how = 'left', on = pct_df.index)
df = df.rename(columns={'key_0' : '날짜'})
df_all = pd.merge(df, cpi, how = 'left', on = pct_df.index)
df_all = df_all.drop('key_0', axis=1)

# book_df = df[['날짜', '서적/문구', '소매판매지수']]
df_all.to_csv('./data/df_all.csv', index=0)

# %%
# 상관계수 히트맵

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc 

rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False 

plt.figure(figsize=(16,10))

sns.heatmap(df_all.corr(), annot=True)

plt.show()

# %%
# book_df["날짜"] = pd.to_datetime(book_df["날짜"], format='%Y%m')     # 데이터 타입 datetime으로 변경
# book_df["날짜"] = book_df["날짜"].dt.strftime('%Y%m')                 # datetime 형식 설정
# book_df.set_index("날짜", inplace=True)                              # 날짜 컬럼 인덱스 설정

# %%
book_df[["소비"]] = "" 
book_df
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/2359539253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df[["소비"]] = ""
#          날짜  서적/문구     소매판매지수 소비
# 0    201001  -14.5  -9.508197
# 1    201002   -6.2  -1.690821
# 2    201003   54.4   5.405405
# 3    201004  -30.9  -1.864802
# 4    201005   -5.8   4.275534
# ..      ...    ...        ... ..
# 143  202112   18.6   2.004812
# 144  202201   -5.1  -7.625786
# 145  202202  -16.4  -8.170213
# 146  202203   40.3  13.067655
# 147  202204  -19.5  -2.131148
#
# [148 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc 

rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False 

plt.figure(figsize=(16,10))

sns.heatmap(book_df.corr(), annot=True)

plt.show()

# %%
book_df[book_df["소비"]==""]
# Out:
#          날짜  서적/문구     소매판매지수 소비
# 0    201001  -14.5  -9.508197
# 1    201002   -6.2  -1.690821
# 2    201003   54.4   5.405405
# 3    201004  -30.9  -1.864802
# 4    201005   -5.8   4.275534
# ..      ...    ...        ... ..
# 143  202112   18.6   2.004812
# 144  202201   -5.1  -7.625786
# 145  202202  -16.4  -8.170213
# 146  202203   40.3  13.067655
# 147  202204  -19.5  -2.131148
#
# [148 rows x 4 columns]

# %%
# book_df["날짜"] = pd.to_datetime(book_df["날짜"], format='%Y/%m')     # 데이터 타입 datetime으로 변경
# book_df["날짜"] = book_df["날짜"].dt.strftime('%Y%m')                 # datetime 형식 설정
# # book_df.set_index("날짜", inplace=True)

# %%
book_df['날짜'] = book_df['날짜'].astype(str)
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/2950536731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df['날짜'] = book_df['날짜'].astype(str)

# %%
book_df['월'] = book_df['날짜'].str[-2:]
book_df['월'] = book_df['월'].astype(int)
book_df
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3967023149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df['월'] = book_df['날짜'].str[-2:]
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3967023149.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df['월'] = book_df['월'].astype(int)
#          날짜  서적/문구     소매판매지수 소비   월
# 0    201001  -14.5  -9.508197      1
# 1    201002   -6.2  -1.690821      2
# 2    201003   54.4   5.405405      3
# 3    201004  -30.9  -1.864802      4
# 4    201005   -5.8   4.275534      5
# ..      ...    ...        ... ..  ..
# 143  202112   18.6   2.004812     12
# 144  202201   -5.1  -7.625786      1
# 145  202202  -16.4  -8.170213      2
# 146  202203   40.3  13.067655      3
# 147  202204  -19.5  -2.131148      4
#
# [148 rows x 5 columns]

# %%
book_m = book_df.groupby('월').mean()
book_m
# Out:
#         서적/문구     소매판매지수
# 월
# 1   -9.446154  -6.858107
# 2   -7.723077  -6.870708
# 3   40.161538  10.189673
# 4  -23.476923  -1.704188
# 5   -1.708333   4.921439
# 6   -4.941667  -3.555443
# 7   11.325000   0.622371
# 8   -6.008333  -2.609243
# 9    3.391667   4.595584
# 10  -5.558333   1.800316
# 11   2.250000   1.986734
# 12  17.291667   1.887189

# %%
# 월 등락률 평균
book_m = book_df.groupby('월').mean()
book_m_m = []
sri_m_m = []
for i in range(1, 12):
    book_m_m.append(book_m[book_m.index == i]['서적/문구'])
    sri_m_m.append(book_m[book_m.index == i]['소매판매지수'])

print(book_m_m[0])
print(sri_m_m[0])
print(book_m[book_m.index == 1]['서적/문구'])
# Out:
# 월
# 1   -9.446154
# Name: 서적/문구, dtype: float64
# 월
# 1   -6.858107
# Name: 소매판매지수, dtype: float64
# 월
# 1   -9.446154
# Name: 서적/문구, dtype: float64

# %%
year = 13
book_u = []
book_d = []
sri_u = []
sri_d = []
all_book_u = book_df['서적/문구'][book_df['서적/문구']>0].mean()
all_book_d = book_df['서적/문구'][book_df['서적/문구']<0].mean()
all_sri_u = book_df['소매판매지수'][book_df['소매판매지수']>0].mean()
all_sri_d = book_df['소매판매지수'][book_df['소매판매지수']<0].mean()

for i in range(0, 86 ,12):
    b_u = book_df.loc[i:i+11][book_df['서적/문구'] > 0]
    b_d = book_df.loc[i:i+11][book_df['서적/문구'] < 0]
    s_u = book_df.loc[i:i+11][book_df['소매판매지수'] > 0]
    s_d = book_df.loc[i:i+11][book_df['소매판매지수'] < 0]
    
    book_u.insert(year, b_u['서적/문구'].mean())
    book_d.insert(year, b_d['서적/문구'].mean())
    sri_u.insert(year, s_u['소매판매지수'].mean())
    sri_d.insert(year, s_d['소매판매지수'].mean())

print("상승 등락: ", book_u)
print("하락 등락 : ", book_d)
print("지수 상승 등락 평균 : ", sri_u)
print("지수 하강 등락 평균 : ", sri_d)
print("전체 상승 등락 : ", all_book_u)
print("전체 하강 등락 : ", all_book_d)
print("전체 지수 상승 : ", all_sri_u)
print("전체 지수 하강 : ", all_sri_d)

#리스트[0] = book_df[0:11]
#리스트[1] = book_df[12:23]
#리스트[2] = book_df[24:35]
#리스트[3] = book_df[36:47]
#리스트[4] = book_df[48:59]
#리스트[5] = book_df[60:71]
#리스트[6] = book_df[72:83]
# Out:
# 상승 등락:  [16.55, 19.479999999999997, 12.299999999999999, 16.54, 17.0, 25.049999999999997, 15.88, 17.08]
# 하락 등락 :  [-12.149999999999999, -9.671428571428573, -12.049999999999999, -9.5, -9.8, -9.424999999999999, -9.214285714285714, -9.928571428571429]
# 지수 상승 등락 평균 :  [3.4148156349332814, 5.4763364533239045, 4.616846083457541, 3.522166779600067, 4.271365513251891, 4.540162231170582, 4.071448435156551, 5.904687339697099]
# 지수 하강 등락 평균 :  [-3.7789309573435474, -3.249761610257519, -4.0083281586653134, -4.656922424514482, -4.613775629638037, -4.419418389955343, -3.516958705148219, -3.7366209542979223]
# 전체 상승 등락 :  15.917741935483871
# 전체 하강 등락 :  -9.310465116279067
# 전체 지수 상승 :  4.334180837747845
# 전체 지수 하강 :  -4.209304470550225
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3140752197.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b_u = book_df.loc[i:i+11][book_df['서적/문구'] > 0]
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3140752197.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b_d = book_df.loc[i:i+11][book_df['서적/문구'] < 0]
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3140752197.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   s_u = book_df.loc[i:i+11][book_df['소매판매지수'] > 0]
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/3140752197.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   s_d = book_df.loc[i:i+11][book_df['소매판매지수'] < 0]

# %%
print("상승 등락: ", book_u)
print("하락 등락 : ", book_d)
print("지수 상승 등락 평균 : ", sri_u)
print("지수 하강 등락 평균 : ", sri_d)
print("전체 상승 등락 : ", all_book_u)
print("전체 하강 등락 : ", all_book_d)
print("전체 지수 상승 : ", all_sri_u)
print("전체 지수 하강 : ", all_sri_d)
# Out:
# 상승 등락:  [16.55, 19.479999999999997, 12.299999999999999, 16.54, 17.0, 25.049999999999997, 15.88, 17.08]
# 하락 등락 :  [-12.149999999999999, -9.671428571428573, -12.049999999999999, -9.5, -9.8, -9.424999999999999, -9.214285714285714, -9.928571428571429]
# 지수 상승 등락 평균 :  [3.4148156349332814, 5.4763364533239045, 4.616846083457541, 3.522166779600067, 4.271365513251891, 4.540162231170582, 4.071448435156551, 5.904687339697099]
# 지수 하강 등락 평균 :  [-3.7789309573435474, -3.249761610257519, -4.0083281586653134, -4.656922424514482, -4.613775629638037, -4.419418389955343, -3.516958705148219, -3.7366209542979223]
# 전체 상승 등락 :  15.917741935483871
# 전체 하강 등락 :  -9.310465116279067
# 전체 지수 상승 :  4.334180837747845
# 전체 지수 하강 :  -4.209304470550225

# %%
book_df[book_df['월'] == 7]
# Out:
#          날짜  서적/문구    소매판매지수 소비  월
# 6    201007    4.8  1.393728     7
# 18   201107   11.1 -0.437637     7
# 30   201207   12.3  1.941748     7
# 42   201307   16.0  2.253219     7
# 54   201407   19.2  2.010582     7
# 66   201507   19.0  3.052632     7
# 78   201607   14.5 -1.257253     7
# 90   201707   10.9  0.671785     7
# 102  201807   10.1  1.931923     7
# 114  201907    7.8  0.454545     7
# 126  202007    1.1 -5.132592     7
# 138  202107    9.1  0.585774     7

# %%
book_m
# Out:
#         서적/문구     소매판매지수
# 월
# 1   -9.446154  -6.858107
# 2   -7.723077  -6.870708
# 3   40.161538  10.189673
# 4  -23.476923  -1.704188
# 5   -1.708333   4.921439
# 6   -4.941667  -3.555443
# 7   11.325000   0.622371
# 8   -6.008333  -2.609243
# 9    3.391667   4.595584
# 10  -5.558333   1.800316
# 11   2.250000   1.986734
# 12  17.291667   1.887189

# %%
# print("상승 등락: ", book_u)
# print("하락 등락 : ", book_d)
# print("지수 상승 등락 평균 : ", sri_u)
# print("지수 하강 등락 평균 : ", sri_d)
# print("전체 상승 등락 : ", all_book_u)
# print("전체 하강 등락 : ", all_book_d)
# print("전체 지수 상승 : ", all_sri_u)
# print("전체 지수 하강 : ", all_sri_d)
# 단순 등락들은 리스트 0~6 첫1년:13년도 ~ 7년 : 19년도
# (a[int(j/12)])

import numpy as np

book_df["날짜"] = book_df["날짜"].astype(str)
book_df["소비"] = ""

for i in range(0,len(book_df) ):
    #1차 노드
    if book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values > 0:
        #2차 노드
        if book_df.loc[i, '서적/문구'] > 0:
            #3차 노드
            if book_df.loc[i, '서적/문구'] > book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values:
                book_df.loc[i,"소비"] = 1
            elif book_df.loc[i, '서적/문구'] < book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values:
                if book_df.loc[i,"소매판매지수"] > book_m['소매판매지수'][book_m.index == book_df.loc[i,'월']].values:
                    book_df.loc[i, '소비'] = 1
                else:
                    book_df.loc[i, '소비'] = 0
        elif book_df.loc[i, '서적/문구'] < 0:
            if book_df.loc[i,"소매판매지수"] < 0:
                book_df.loc[i, '소비'] = 0
            elif book_df.loc[i,"소매판매지수"] > 0:
                if book_df.loc[i,"소매판매지수"] > book_m['소매판매지수'][book_m.index == book_df.loc[i,'월']].values:
                    book_df.loc[i, '소비'] = 1
                else:
                    book_df.loc[i, '소비'] = 0
            else:
                book_df.loc[i, '소비'] = 0
    elif book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values < 0:
        if book_df.loc[i, '서적/문구'] < 0:
            if book_df.loc[i, '서적/문구'] < book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values:
                book_df.loc[i, '소비'] = 0
            elif book_df.loc[i, '서적/문구'] > book_m['서적/문구'][book_m.index == book_df.loc[i,'월']].values:
                if book_df.loc[i, '서적/문구'] < 0:
                    book_df.loc[i, '소비'] = 0
                elif book_df.loc[i,"소매판매지수"] < book_m['소매판매지수'][book_m.index == book_df.loc[i,'월']].values:
                    book_df.loc[i, '소비'] = 1
                else:
                    book_df.loc[i, '소비'] = 0
        elif book_df.loc[i, '서적/문구'] > 0:
            if book_df.loc[i,"소매판매지수"] > 0:
                book_df.loc[i, '소비'] = 1
            elif book_df.loc[i,"소매판매지수"] < 0:
                if book_df.loc[i,"소매판매지수"] < book_m['소매판매지수'][book_m.index == book_df.loc[i,'월']].values:
                    book_df.loc[i, '소비'] = 0
                else:
                    book_df.loc[i, '소비'] = 1




    # for i in range(0, 13):
    #     for j in range(12, 85):
    #         if (book_df.loc[i,"서적/문구"] >= 0) & (book_df.loc[i,"소매판매지수"] > 0):
    #             book_df.loc[i,"소비"] = 1
    #         elif (book_df.loc[i,"서적/문구"] >= 0) & (book_df.loc[i,"소매판매지수"] < 0):
    #             book_df.loc[i,"소비"] = 1
    #         elif ((book_df.loc[i,"서적/문구"] < 0) >= book_df["서적/문구"].quantile(q=0.5)) & (book_df.loc[i,"소매판매지수"] > 0):
    #             book_df.loc[i,"소비"] = 1
    #         else:
    #             book_df.loc[i,"소비"] = 0
    #         if (book_df["서적/문구"].loc[j-12] > 0) & (book_df["서적/문구"].loc[j] > 0):
    #             book_df.loc[j,"소비"] = 1
    #         elif (book_df["서적/문구"].loc[j-12] < 0) & (book_df["서적/문구"].loc[j] > 0):
    #             if ((book_df["서적/문구"].loc[j-12]) >= book_df["서적/문구"].quantile(q=0.5)) & ((book_df.loc[j,"소매판매지수"]) > book_df["소매판매지수"].quantile(q=0.75)):
    #                 book_df.loc[j,"소비"] = 1
    #             else :
    #                 book_df.loc[j,"소비"] = 0

    #         elif (book_df["서적/문구"].loc[j-12] > 0) & (book_df["서적/문구"].loc[j] < 0):
    #             if (book_df["서적/문구"].loc[j] > book_df["서적/문구"].quantile(q = 0.5)) & ((book_df.loc[j,"소매판매지수"]) > book_df["소매판매지수"].quantile(q=0.75)):
    #                 book_df.loc[j,"소비"] = 1
    #             else:
    #                 book_df.loc[j,"소비"] = 0
    #         else:
    #             book_df.loc[j,"소비"] = 0
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/1454126612.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_13760/1454126612.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""

# %%
book_df.groupby('월').mean()
# Out:
#         서적/문구     소매판매지수
# 월
# 1   -9.446154  -6.858107
# 2   -7.723077  -6.870708
# 3   40.161538  10.189673
# 4  -23.476923  -1.704188
# 5   -1.708333   4.921439
# 6   -4.941667  -3.555443
# 7   11.325000   0.622371
# 8   -6.008333  -2.609243
# 9    3.391667   4.595584
# 10  -5.558333   1.800316
# 11   2.250000   1.986734
# 12  17.291667   1.887189

# %%
book_df[book_df['월']==12]
# Out:
#          날짜  서적/문구    소매판매지수 소비   월
# 11   201012   25.0  3.594771  1  12
# 23   201112   18.3  4.380342  1  12
# 35   201212   11.8  2.358974  1  12
# 47   201312   16.8  1.215805  0  12
# 59   201412   14.2  5.200000  1  12
# 71   201512   28.1  2.539981  1  12
# 83   201612   16.4  1.924840  1  12
# 95   201712   18.0 -1.826087  1  12
# 107  201812   16.0  0.172117  0  12
# 119  201912   12.2  0.996678  0  12
# 131  202012   12.1  0.084034  0  12
# 143  202112   18.6  2.004812  1  12

# %%
book_df.groupby('월').mean()
# Out:
#         서적/문구     소매판매지수
# 월
# 1   -9.446154  -6.858107
# 2   -7.723077  -6.870708
# 3   40.161538  10.189673
# 4  -23.476923  -1.704188
# 5   -1.708333   4.921439
# 6   -4.941667  -3.555443
# 7   11.325000   0.622371
# 8   -6.008333  -2.609243
# 9    3.391667   4.595584
# 10  -5.558333   1.800316
# 11   2.250000   1.986734
# 12  17.291667   1.887189

# %%
book_m['서적/문구'][book_m.index == book_df.loc[1,'월']].values
# Out:
# array([-7.72307692])

# %%
import pandas as pd 

pd.set_option('display.max_rows', None)

# %%
book_df
# Out:
#          날짜  서적/문구     소매판매지수 소비   월
# 0    201001  -14.5  -9.508197  0   1
# 1    201002   -6.2  -1.690821  0   2
# 2    201003   54.4   5.405405  1   3
# 3    201004  -30.9  -1.864802  0   4
# 4    201005   -5.8   4.275534  0   5
# 5    201006    8.0  -1.936219  1   6
# 6    201007    4.8   1.393728  1   7
# 7    201008   -7.4  -3.894616  0   8
# 8    201009    1.9   6.793802  1   9
# 9    201010   -8.1   1.227679  0  10
# 10   201011    5.2   1.212789  1  11
# 11   201012   25.0   3.594771  1  12
# 12   201101  -16.6  -3.470032  0   1
# 13   201102   -4.9 -11.982571  0   2
# 14   201103   53.8  12.128713  1   3
# 15   201104  -28.6  -1.214128  0   4
# 16   201105   -5.0   4.581006  0   5
# 17   201106   -4.9  -2.350427  0   6
# 18   201107   11.1  -0.437637  0   7
# 19   201108   -4.7  -3.186813  0   8
# 20   201109    8.1   4.994325  1   9
# 21   201110   -3.0   1.297297  0  10
# 22   201111    6.1  -0.106724  1  11
# 23   201112   18.3   4.380342  1  12
# 24   201201  -13.7  -3.991812  0   1
# 25   201202    3.9  -8.955224  0   2
# 26   201203   22.5   7.377049  0   3
# 27   201204  -25.5  -1.962923  0   4
# 28   201205   -4.3   7.007786  0   5
# 29   201206   -4.0  -3.638254  0   6
# 30   201207   12.3   1.941748  1   7
# 31   201208   -9.9  -5.396825  0   8
# 32   201209   14.3   6.599553  1   9
# 33   201210  -14.9  -0.104932  0  10
# 34   201211    9.0   2.415966  1  11
# 35   201212   11.8   2.358974  1  12
# 36   201301   -6.9  -8.617234  0   1
# 37   201302  -10.7  -4.824561  0   2
# 38   201303   47.1   7.834101  1   3
# 39   201304  -20.5  -1.816239  0   4
# 40   201305  -10.4   5.223069  0   5
# 41   201306   -8.0  -3.619442  0   6
# 42   201307   16.0   2.253219  1   7
# 43   201308   -8.8  -4.407135  0   8
# 44   201309    1.4   3.183315  0   9
# 45   201310   -1.2   3.297872  0  10
# 46   201311    1.4   1.647786  0  11
# 47   201312   16.8   1.215805  0  12
# 48   201401  -10.4  -3.503504  0   1
# 49   201402   -8.1 -10.062241  0   2
# 50   201403   45.9  10.380623  1   3
# 51   201404  -28.6  -3.343783  0   4
# 52   201405   -2.1   6.054054  0   5
# 53   201406   -9.1  -3.669725  0   6
# 54   201407   19.2   2.010582  1   7
# 55   201408   -6.8  -2.489627  0   8
# 56   201409    2.0   1.808511  0   9
# 57   201410   -3.5   1.776385  0  10
# 58   201411    3.7   2.669405  1  11
# 59   201412   14.2   5.200000  1  12
# 60   201501   -7.5 -10.456274  0   1
# 61   201502  -11.7  -1.380042  0   2
# 62   201503   51.5   6.781485  1   3
# 63   201504  -26.3  -0.504032  0   4
# 64   201505   -4.6   3.951368  0   5
# 65   201506   -9.0  -7.407407  0   6
# 66   201507   19.0   3.052632  1   7
# 67   201508   -8.0  -2.349336  0   8
# 68   201509    1.6   6.903766  1   9
# 69   201510   -2.2   4.011742  0  10
# 70   201511   -6.1   0.000000  0  11
# 71   201512   28.1   2.539981  1  12
# 72   201601  -11.1  -8.623853  0   1
# 73   201602   -7.6  -4.016064  0   2
# 74   201603   45.6   9.309623  1   3
# 75   201604  -28.4  -2.296651  0   4
# 76   201605   -3.1   5.093046  0   5
# 77   201606   -3.4  -3.634669  0   6
# 78   201607   14.5  -1.257253  1   7
# 79   201608   -8.5  -1.273262  0   8
# 80   201609    0.9   1.388889  0   9
# 81   201610   -2.4   6.066536  0  10
# 82   201611    2.0   0.645756  0  11
# 83   201612   16.4   1.924840  1  12
# 84   201701  -14.1  -7.104317  0   1
# 85   201702   -0.6  -7.841239  0   2
# 86   201703   41.1  10.714286  1   3
# 87   201704  -26.5  -1.423150  0   4
# 88   201705   -3.5   3.561116  0   5
# 89   201706   -3.0  -3.159851  0   6
# 90   201707   10.9   0.671785  1   7
# 91   201708   -5.1  -3.431840  0   8
# 92   201709    7.8   8.094768  1   9
# 93   201710  -16.7  -1.369863  0  10
# 94   201711    7.6   6.481481  1  11
# 95   201712   18.0  -1.826087  1  12
# 96   201801  -11.5  -6.731621  0   1
# 97   201802   -7.5  -3.418803  0   2
# 98   201803   47.7  11.406096  1   3
# 99   201804  -27.7  -3.000883  0   4
# 100  201805    2.4   2.638763  1   5
# 101  201806   -5.3  -3.634752  0   6
# 102  201807   10.1   1.931923  1   7
# 103  201808   -3.1  -3.429603  0   8
# 104  201809    1.0   2.803738  0   9
# 105  201810   -5.3   3.272727  0  10
# 106  201811    1.9   2.288732  1  11
# 107  201812   16.0   0.172117  0  12
# 108  201901   -4.1  -5.670103  0   1
# 109  201902  -10.7  -9.107468  0   2
# 110  201903   43.0  16.232465  1   3
# 111  201904  -26.6  -3.965517  0   4
# 112  201905    0.6   4.667864  1   5
# 113  201906   -4.4  -5.660377  0   6
# 114  201907    7.8   0.454545  0   7
# 115  201908   -1.6   0.904977  0   8
# 116  201909   -2.4   1.614350  0   9
# 117  201910   -3.3   2.118270  0  10
# 118  201911    2.1   4.062230  1  11
# 119  201912   12.2   0.996678  0  12
# 120  202001   -6.2  -8.059211  0   1
# 121  202002  -10.8 -12.522361  0   2
# 122  202003   -4.9   9.304703  0   3
# 123  202004    3.5   1.870907  1   4
# 124  202005   10.8   8.723600  1   5
# 125  202006   -8.4  -1.266892  0   6
# 126  202007    1.1  -5.132592  0   7
# 127  202008   -2.9   0.721371  0   8
# 128  202009   -0.7   5.640107  1   9
# 129  202010   -5.2  -1.864407  0  10
# 130  202011   -0.5   2.763385  1  11
# 131  202012   12.1   0.084034  0  12
# 132  202101   -1.1  -5.793451  0   1
# 133  202102   -9.1  -5.347594  0   2
# 134  202103   34.1  12.523540  1   3
# 135  202104  -19.6  -0.502092  0   4
# 136  202105    4.5   3.280067  1   5
# 137  202106   -7.8  -2.687296  0   6
# 138  202107    9.1   0.585774  0   7
# 139  202108   -5.3  -3.078203  0   8
# 140  202109    4.8   5.321888  1   9
# 141  202110   -0.9   1.874491  0  10
# 142  202111   -5.4  -0.240000  0  11
# 143  202112   18.6   2.004812  1  12
# 144  202201   -5.1  -7.625786  0   1
# 145  202202  -16.4  -8.170213  0   2
# 146  202203   40.3  13.067655  1   3
# 147  202204  -19.5  -2.131148  0   4

# %%
book_df['소비'] = book_df['소비'].astype(int)
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_12099/857023347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df['소비'] = book_df['소비'].astype(int)

# %%
book_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 0 to 147
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      148 non-null    object
#  1   서적/문구   148 non-null    float64
#  2   소매판매지수  148 non-null    float64
#  3   소비      148 non-null    int64
#  4   월       148 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 11.0+ KB

# %%
data = book_df[['날짜', '월', '서적/문구', '소매판매지수']]
target = book_df['소비']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier

# %%
ss.fit(data)
# Out:
# StandardScaler()

# %%
data_scaled = ss.transform(data)

# %%
params = {'C' : [0, 0.1, 1, 10, 20]}

# %%
lr = LogisticRegression()
rg = Ridge()
ls = Lasso()
logisticreg = LogisticRegression()
detreec = DecisionTreeClassifier()
randomforest = RandomForestClassifier()
# xgb = XGBClassifier()

# %%
splitter = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
scores_logistic = cross_validate(lr, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
scores_ridge = cross_validate(rg, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
scores_lasso = cross_validate(ls, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
scores_logisticreg = cross_validate(logisticreg, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
scores_dectree = cross_validate(detreec, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
scores_randomforest = cross_validate(randomforest, data, target, cv=splitter, n_jobs=-1, return_train_score=True)
# scores_xgb = cross_validate(xgb, data, target, cv=splitter, n_jobs=-1, return_train_score=True)

# %%
print('로지스틱 train data score : ',np.mean(scores_logistic['train_score'])) 
print('로지스틱 test data score : ',np.mean(scores_logistic['test_score']))  
print('릿지 train data score : ',np.mean(scores_ridge['train_score'])) 
print('릿지 test data score : ',np.mean(scores_ridge['test_score']))  
print('라쏘 train data score : ', np.mean(scores_lasso['train_score'])) 
print('라쏘 test data score : ', np.mean(scores_lasso['test_score'])) 
print('결정트리(Decision Tree) train data score : ',np.mean(scores_dectree['train_score']))
print('결정트리(Decision Tree) test data score : ',np.mean(scores_dectree['test_score']))
print('랜덤포레스트 train data score : ',np.mean(scores_randomforest['train_score']))
print('랜덤포레스트 test data score : ',np.mean(scores_randomforest['test_score']))
# print('XGB train data score : ',np.mean(scores_xgb['train_score']))
# print('XGB test data score : ',np.mean(scores_xgb['test_score']))
# Out:
# 로지스틱 train data score :  0.8608160678380977
# 로지스틱 test data score :  0.8444444444444446
# 릿지 train data score :  0.5151677568939942
# 릿지 test data score :  0.49671909952847865
# 라쏘 train data score :  0.4500998891215621
# 라쏘 test data score :  0.4422211873577466
# 결정트리(Decision Tree) train data score :  1.0
# 결정트리(Decision Tree) test data score :  0.8655555555555555
# 랜덤포레스트 train data score :  1.0
# 랜덤포레스트 test data score :  0.8716666666666667

# %%
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.3, random_state=9)

# %%
df_clf = DecisionTreeClassifier()

# %%
df_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_pred = df_clf.predict(X_test)

# %%
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test, X_pred)))
# Out:
# 예측 정확도: 0.8889

# %%
plt.plot(y_test, 'o',c='red')
plt.plot(X_pred, 'o',c='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
book_df.columns
# Out:
# Index(['날짜', '서적/문구', '소매판매지수', '소비', '월'], dtype='object')

# %%
from sklearn.tree import plot_tree
from matplotlib import rc 

rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False 

feature_names = ['날짜', '서적/문구', '소매판매지수', '월']
# data = book_df[['날짜', '월', '서적/문구', '소매판매지수']]
# target = book_df['소비']
plt.figure(figsize=(16,10))
plot_tree(df_clf, filled=True, feature_names=feature_names, node_ids=True, proportion=True)
plt.show()

# %%
df_clf.feature_importances_
# Out:
# array([0.10638366, 0.        , 0.73058204, 0.1630343 ])

# %%
# 피처 중요도 시각화
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc 

rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False 

plt.title("피처중요도")
sns.barplot(x=df_clf.feature_importances_, y=data.columns)
# Out:
# <AxesSubplot:title={'center':'피처중요도'}>

# %%
# **머신러닝**:

# - Decision Tree
# - Random Forest
# - XGBoost

# %%
## 80대 20으로
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.2, random_state=61)

# %%
#다른 라이브러리로 비교해보는 것도 좋을 듯

from sklearn.base import BaseEstimator
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

be_clf = RandomForestClassifier()
be_clf.fit(X_train, y_train)

pred = be_clf.predict(X_test)

print(f'정확도 : {accuracy_score(y_test, pred)}')
print(f'정밀도 TP/(FP+TP) : {precision_score(y_test, pred)}')
print(f'재현율 TP/(FN+TP) : {recall_score(y_test, pred)}')
## precision과 recall은 상충관계에 있었다? trade off관계?

## 왜 실행떄마다 값이 바뀔까
# Out:
# 정확도 : 0.8333333333333334
# 정밀도 TP/(FP+TP) : 0.7272727272727273
# 재현율 TP/(FN+TP) : 0.8

# %%
from sklearn.metrics import f1_score

print(f'f1 score : {f1_score(y_test, pred)}')
# Out:
# f1 score : 0.761904761904762

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)

pred_proba = lr_clf.predict_proba(X_test) ## 확률값 리턴 위해
pred = lr_clf.predict(X_test)

#print(pred)
#print(pred_proba) ## 타이타닉 경우의 수 2 생,사
#print(f'shape : {pred_proba.shape}')

pred_proba_result = np.concatenate([pred_proba, pred.reshape(-1, 1)], axis=1)
print("두 개의 class중 더 큰 확률을 클래스 값으로 예측 \n", pred_proba_result[:3])
# Out:
# 두 개의 class중 더 큰 확률을 클래스 값으로 예측
#  [[0.27131243 0.72868757 1.        ]
#  [0.49844652 0.50155348 1.        ]
#  [0.56278708 0.43721292 0.        ]]

# %%
from sklearn.metrics import precision_recall_curve
#레이블 값이 1일때의 예측 확률
pred_proba_class1 = lr_clf.predict_proba(X_test)[:,1]

#실제 데이터 셋과 레이블 값이 1일때 예측확률을 커브 인자로 입력
precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_class1)
print("반환 분류 결정 임계값 배열의 Shape : ", thresholds.shape)
print("반환된 precisions 배열의 shape : ", precisions.shape)
print("q반환된 recalls 배열의 shape : ", recalls.shape)

print("thresholds 5sample : ", thresholds[:5])
print("precisions 5sample : ", precisions[:5])
print("recalls 5sample : ", recalls[:5])

#반환된 임계값 배열 로우가 147건이니까 샘플로 10건, 임계값을 15step으로 추출
thr_index = np.arange(0, thresholds.shape[0], 15)
print("샘플 추출 위한 임계값 배열의 index 10개 : ", thr_index)
print("샘플용 10개의 임계값 : ", np.round(thresholds[thr_index], 2))

#15step 단위로 추출된 이계값에 따른 정밀도와 재현율 값
print("샘플 임계값별 정밀도 : ", np.round(precisions[thr_index], 3))
print("샘플 임계값별 재현율 : ", np.round(recalls[thr_index], 3))
# Out:
# 반환 분류 결정 임계값 배열의 Shape :  (30,)
# 반환된 precisions 배열의 shape :  (31,)
# q반환된 recalls 배열의 shape :  (31,)
# thresholds 5sample :  [0.00064911 0.0007782  0.00084815 0.00203164 0.00489169]
# precisions 5sample :  [0.33333333 0.34482759 0.35714286 0.37037037 0.38461538]
# recalls 5sample :  [1. 1. 1. 1. 1.]
# 샘플 추출 위한 임계값 배열의 index 10개 :  [ 0 15]
# 샘플용 10개의 임계값 :  [0.   0.23]
# 샘플 임계값별 정밀도 :  [0.333 0.667]
# 샘플 임계값별 재현율 :  [1. 1.]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

def precision_recall_curve_plot(y_test, pred_proba_c1):
    #threshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
    
    #x축을 threshold값으로 y축은 정밀도, 재현율 값으로 각각 plot 수행, 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle = '--', label = 'precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label = 'recall')
    
    #threshold 값 x축의 scale을 0.1단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1), 2))
    
    #x축, y축 label과 legend, 그리고 grid 설정
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()

precision_recall_curve_plot(y_test, lr_clf.predict_proba(X_test)[:, 1])

# %%
book_df['날짜'] = book_df['날짜'].astype(int)
data = book_df[['날짜', '월', '서적/문구', '소매판매지수']]
target = book_df['소비']
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_12099/2784616320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df['날짜'] = book_df['날짜'].astype(int)

# %%
#XGBoosting 따로 install해야
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.2, random_state=13)

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score


# Extreme Gradient Boosting (xgboost) 모델 사용

# 1. 모델 선언
xgb  = XGBClassifier()

# 2. 모델 훈련 fit()함수
xgb.fit(X_train, y_train)

# 3. 모델 예측 predict()함수
y_pred = xgb.predict(X_test)

# 4. score()
#xgb.score(X_train, y_train)
acc = accuracy_score(y_pred, y_test)
print(acc)

## 병렬처리 연산이라 속도가 빠름
# Out:
# 0.9666666666666667

# %%
plt.plot(y_test, 'o',c='red')
plt.plot(X_pred, 'o',c='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
book_train = book_df[0:-13]
book_test = book_df[-13:-1]
book_train
# Out:
#          날짜  서적/문구     소매판매지수  소비   월
# 0    201001  -14.5  -9.508197   0   1
# 1    201002   -6.2  -1.690821   0   2
# 2    201003   54.4   5.405405   1   3
# 3    201004  -30.9  -1.864802   0   4
# 4    201005   -5.8   4.275534   0   5
# 5    201006    8.0  -1.936219   1   6
# 6    201007    4.8   1.393728   1   7
# 7    201008   -7.4  -3.894616   0   8
# 8    201009    1.9   6.793802   1   9
# 9    201010   -8.1   1.227679   0  10
# 10   201011    5.2   1.212789   1  11
# 11   201012   25.0   3.594771   1  12
# 12   201101  -16.6  -3.470032   0   1
# 13   201102   -4.9 -11.982571   0   2
# 14   201103   53.8  12.128713   1   3
# 15   201104  -28.6  -1.214128   0   4
# 16   201105   -5.0   4.581006   0   5
# 17   201106   -4.9  -2.350427   0   6
# 18   201107   11.1  -0.437637   0   7
# 19   201108   -4.7  -3.186813   0   8
# 20   201109    8.1   4.994325   1   9
# 21   201110   -3.0   1.297297   0  10
# 22   201111    6.1  -0.106724   1  11
# 23   201112   18.3   4.380342   1  12
# 24   201201  -13.7  -3.991812   0   1
# 25   201202    3.9  -8.955224   0   2
# 26   201203   22.5   7.377049   0   3
# 27   201204  -25.5  -1.962923   0   4
# 28   201205   -4.3   7.007786   0   5
# 29   201206   -4.0  -3.638254   0   6
# 30   201207   12.3   1.941748   1   7
# 31   201208   -9.9  -5.396825   0   8
# 32   201209   14.3   6.599553   1   9
# 33   201210  -14.9  -0.104932   0  10
# 34   201211    9.0   2.415966   1  11
# 35   201212   11.8   2.358974   1  12
# 36   201301   -6.9  -8.617234   0   1
# 37   201302  -10.7  -4.824561   0   2
# 38   201303   47.1   7.834101   1   3
# 39   201304  -20.5  -1.816239   0   4
# 40   201305  -10.4   5.223069   0   5
# 41   201306   -8.0  -3.619442   0   6
# 42   201307   16.0   2.253219   1   7
# 43   201308   -8.8  -4.407135   0   8
# 44   201309    1.4   3.183315   0   9
# 45   201310   -1.2   3.297872   0  10
# 46   201311    1.4   1.647786   0  11
# 47   201312   16.8   1.215805   0  12
# 48   201401  -10.4  -3.503504   0   1
# 49   201402   -8.1 -10.062241   0   2
# 50   201403   45.9  10.380623   1   3
# 51   201404  -28.6  -3.343783   0   4
# 52   201405   -2.1   6.054054   0   5
# 53   201406   -9.1  -3.669725   0   6
# 54   201407   19.2   2.010582   1   7
# 55   201408   -6.8  -2.489627   0   8
# 56   201409    2.0   1.808511   0   9
# 57   201410   -3.5   1.776385   0  10
# 58   201411    3.7   2.669405   1  11
# 59   201412   14.2   5.200000   1  12
# 60   201501   -7.5 -10.456274   0   1
# 61   201502  -11.7  -1.380042   0   2
# 62   201503   51.5   6.781485   1   3
# 63   201504  -26.3  -0.504032   0   4
# 64   201505   -4.6   3.951368   0   5
# 65   201506   -9.0  -7.407407   0   6
# 66   201507   19.0   3.052632   1   7
# 67   201508   -8.0  -2.349336   0   8
# 68   201509    1.6   6.903766   1   9
# 69   201510   -2.2   4.011742   0  10
# 70   201511   -6.1   0.000000   0  11
# 71   201512   28.1   2.539981   1  12
# 72   201601  -11.1  -8.623853   0   1
# 73   201602   -7.6  -4.016064   0   2
# 74   201603   45.6   9.309623   1   3
# 75   201604  -28.4  -2.296651   0   4
# 76   201605   -3.1   5.093046   0   5
# 77   201606   -3.4  -3.634669   0   6
# 78   201607   14.5  -1.257253   1   7
# 79   201608   -8.5  -1.273262   0   8
# 80   201609    0.9   1.388889   0   9
# 81   201610   -2.4   6.066536   0  10
# 82   201611    2.0   0.645756   0  11
# 83   201612   16.4   1.924840   1  12
# 84   201701  -14.1  -7.104317   0   1
# 85   201702   -0.6  -7.841239   0   2
# 86   201703   41.1  10.714286   1   3
# 87   201704  -26.5  -1.423150   0   4
# 88   201705   -3.5   3.561116   0   5
# 89   201706   -3.0  -3.159851   0   6
# 90   201707   10.9   0.671785   1   7
# 91   201708   -5.1  -3.431840   0   8
# 92   201709    7.8   8.094768   1   9
# 93   201710  -16.7  -1.369863   0  10
# 94   201711    7.6   6.481481   1  11
# 95   201712   18.0  -1.826087   1  12
# 96   201801  -11.5  -6.731621   0   1
# 97   201802   -7.5  -3.418803   0   2
# 98   201803   47.7  11.406096   1   3
# 99   201804  -27.7  -3.000883   0   4
# 100  201805    2.4   2.638763   1   5
# 101  201806   -5.3  -3.634752   0   6
# 102  201807   10.1   1.931923   1   7
# 103  201808   -3.1  -3.429603   0   8
# 104  201809    1.0   2.803738   0   9
# 105  201810   -5.3   3.272727   0  10
# 106  201811    1.9   2.288732   1  11
# 107  201812   16.0   0.172117   0  12
# 108  201901   -4.1  -5.670103   0   1
# 109  201902  -10.7  -9.107468   0   2
# 110  201903   43.0  16.232465   1   3
# 111  201904  -26.6  -3.965517   0   4
# 112  201905    0.6   4.667864   1   5
# 113  201906   -4.4  -5.660377   0   6
# 114  201907    7.8   0.454545   0   7
# 115  201908   -1.6   0.904977   0   8
# 116  201909   -2.4   1.614350   0   9
# 117  201910   -3.3   2.118270   0  10
# 118  201911    2.1   4.062230   1  11
# 119  201912   12.2   0.996678   0  12
# 120  202001   -6.2  -8.059211   0   1
# 121  202002  -10.8 -12.522361   0   2
# 122  202003   -4.9   9.304703   0   3
# 123  202004    3.5   1.870907   1   4
# 124  202005   10.8   8.723600   1   5
# 125  202006   -8.4  -1.266892   0   6
# 126  202007    1.1  -5.132592   0   7
# 127  202008   -2.9   0.721371   0   8
# 128  202009   -0.7   5.640107   1   9
# 129  202010   -5.2  -1.864407   0  10
# 130  202011   -0.5   2.763385   1  11
# 131  202012   12.1   0.084034   0  12
# 132  202101   -1.1  -5.793451   0   1
# 133  202102   -9.1  -5.347594   0   2
# 134  202103   34.1  12.523540   1   3

# %%
book_x_train = book_train[['날짜', '서적/문구', '소매판매지수', '월']]
book_y_train = book_train['소비']
book_x_test = book_test[['날짜', '서적/문구', '소매판매지수', '월']]
book_y_test = book_test['소비']

# %%
X_train = book_x_train
X_test = book_x_test
y_train = book_y_train
y_test = book_y_test

# %%
from sklearn.base import BaseEstimator
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

be_clf = RandomForestClassifier()
be_clf.fit(X_train, y_train)

pred = be_clf.predict(X_test)

print(f'정확도 : {accuracy_score(y_test, pred)}')
# Out:
# 정확도 : 0.9166666666666666

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score


# Extreme Gradient Boosting (xgboost) 모델 사용

# 1. 모델 선언
xgb  = XGBClassifier()

# 2. 모델 훈련 fit()함수
xgb.fit(X_train, y_train)

# 3. 모델 예측 predict()함수
y_pred = xgb.predict(X_test)

# 4. score()
#xgb.score(X_train, y_train)
acc = accuracy_score(y_pred, y_test)
print(acc)

## 병렬처리 연산이라 속도가 빠름
# Out:
# 0.9166666666666666

# %%
df_clf = DecisionTreeClassifier(random_state=11)
df_clf.fit(X_train, y_train)
X_pred = df_clf.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test, X_pred)))
# Out:
# 예측 정확도: 0.9167
